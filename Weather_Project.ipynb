# %% [markdown]
# ### Title: Weather Data analysis Real world Project with python
#
#
# * #### LinkedIn profile Link: [My LinkedIn Profile](https://www.linkedin.com/in/tamiriraishe-nyevera-2b51671b5/)
#
#
# * #### Github link:[Github profile](https://github.com/Tamie-AI-Tech)
#
# * #### Kaggle Link: [Kaggle Profile](https://www.kaggle.com/tamiriraishenyevera)

# %% [markdown]
# ### Introduction

# %% [markdown]
# * The weather dataset used in this analysis is a time-series data set with per hour information about the weather condition in 2012. Temp, vissibility, wind speed dew point are recorded
#
# * The data is a csv file and analysis is done using pandas
# * The data will be saved and exported to power bi for good visualisations
# * matplotlib and searbon will be used for some data visualisations to get the inisghts of the data

# %% [markdown]
# #### Questions to answer

# %% [markdown]
# These Questions will be answered under phase3: of the data analysis
#
#
# * find the unique weather of the values in the data
#
# * find the number of times when the weather was exactly 'fog only'
#
# * find the number of times when 'wind speed is exactly is 4km/h'
#
# * What is the mean vissibility
#
# * What is the standard deviation of pressure in this data
#
# * What is the variance of the relative humidity
#
# * Create the column of day_name, month and year
#
# * Find all the instance when wind speed is above 24 and vissibility is 25
#
# * on which day was the humidity high
#
# * which month had the temperatures less than -22 degrees celcius
#
# * find the correlation of the data set and plot the visuals
#
# * find all instances when the snow was recorded
#
# * what was the mean weather monthly
#
# * what is the mean value of each column against each column 'weather column)
#
# * what is the min and max value of each column against each weather condition
#
# They will help in the story telling of in this data

# %% [markdown]
# # Phase 1: Prepare

# %% [markdown]
# This step involves data import,it includes import of libraries that facilitate data import, analysis and visualisation.

# %%
import pandas as pd               #for data loading and manipulation

import numpy as np                #for stastical analysis

import matplotlib.pyplot as plt        #for data visualisation
import seaborn as sns

import matplotlib
# %matplotlib inline

# %%
na_vals = [' ', 'nan', 'Nan', '?', 'missing', 'Missing']      #the list containing all the values that are to be deemed as null values

df = pd.read_csv(r'C:\Users\Tamie\Downloads\python data science projects\datasets\1. Weather Data.csv', na_values = na_vals)


#take note of the dataset directory, click on the dataset that needs to be imported and copy path or
#go to properties >> right click on the dataset >> security >> copy the path that shows beneath written as object name
#take note, on both cases insert r before the path directory.

#The other method inputting r doesnt matter
#import the dataset into the jupyter notebook folder you working on and copy the name of the dataset hence insert it in the parentheses

# %%
df.head(2)              #getting the first 2 rows of data
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
#the size of the dataset
df.shape
# Out:
# (8784, 8)

# %% [markdown]
# The dataset has 8784 rows and 8 columns

# %%
#take note on all of the columns of the dataset
df.columns.to_frame()
# Out:
#                                  0
# Date/Time                Date/Time
# Temp_C                      Temp_C
# Dew Point Temp_C  Dew Point Temp_C
# Rel Hum_%                Rel Hum_%
# Wind Speed_km/h    Wind Speed_km/h
# Visibility_km        Visibility_km
# Press_kPa                Press_kPa
# Weather                    Weather

# %%
#check the data types of the columns
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# The date/Time column has to be set to timestamp in the next phase for the ease of analysis

# %%
#a total of non null values in a dataframe
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# taking into consideration of the shape of the dataste there dont seem to be null or missing values in the dataset

# %% [markdown]
# # Phase 2: Data Processing

# %% [markdown]
# This phase includes all the cleaning, transforming and processing of data

# %% [markdown]
# ### Step 1: Check for all the the missing or na values in the dataset

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# there are no missing values, as predicted by the df.count() method done in the phase one of analysis

# %% [markdown]
# ### Step 2: Checking and handling the data duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates in the dataset

# %% [markdown]
# ### Step 3: Change the data types to more suitable format

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# The date/time column, datatype is object instead of datetime hence it needs to be converted

# %%
#converting the oject datatype to datetime

df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# %%
df['Date/Time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#view 4 rows of the data
df.head(4)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog

# %% [markdown]
# ### Step 3: Rename the columns to have more meaning

# %%
df.rename(columns={'Rel Hum_%':'Relative_Humidity_%', 'Temp_C':'Temperature_C', 'Press_kPa':'Pressure_kPa'}, inplace=True)

#inplace = True makes the changes to apply to the entire dataset

# %% [markdown]
# ### Step 4: format the columns headers to lower cases with the underscore at each space and with lower cases

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.title()

# %% [markdown]
# # Phase 3:  Exploratory Data analysis

# %% [markdown]
# * EDA is an approach to anaylse data inorder to summarize main characteristics of the data
# * It also helps to gain better understanding of the dataset
# * helps uncover relationships between different variables
# * extract the important variables for the problem being solved

# %% [markdown]
# #### Q1: find the unique weather of the values in the data

# %%
#view the dataset
df.head(1)
# Out:
#    Date/Time  Temperature_C  Dew_Point_Temp_C  Relative_Humidity_%  \
# 0 2012-01-01           -1.8              -3.9                   86
#
#    Wind_Speed_Km/H  Visibility_Km  Pressure_Kpa Weather
# 0                4            8.0        101.24     Fog

# %%
#grab the series series or column weather and find the unique values
#unique takes the single appearing values in the dataset
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
#        'Drizzle,Ice Pellets,Fog', 'Drizzle,Snow', 'Rain,Ice Pellets',
#        'Drizzle,Snow,Fog', 'Rain,Snow Grains', 'Rain,Snow,Ice Pellets',
#        'Snow Showers,Fog', 'Moderate Snow,Blowing Snow'], dtype=object)

# %% [markdown]
# #### Q2: find the number of times when the weather was exactly 'fog only'

# %%
filt = df['Weather'] == 'Fog'          #setting up a filtering condition 
df.loc[filt, 'Weather'].count()        #getting the actual count on what or number of conditions that really happened
# Out:
# 150

# %% [markdown]
# the weather was fog 150 times

# %% [markdown]
# #### Q3: find the number of times when 'wind speed is exactly is 4km/h'

# %%
df.head()
# Out:
#             Date/Time  Temperature_C  Dew_Point_Temp_C  Relative_Humidity_%  \
# 0 2012-01-01 00:00:00           -1.8              -3.9                   86
# 1 2012-01-01 01:00:00           -1.8              -3.7                   87
# 2 2012-01-01 02:00:00           -1.8              -3.4                   89
# 3 2012-01-01 03:00:00           -1.5              -3.2                   88
# 4 2012-01-01 04:00:00           -1.5              -3.3                   88
#
#    Wind_Speed_Km/H  Visibility_Km  Pressure_Kpa               Weather
# 0                4            8.0        101.24                   Fog
# 1                4            8.0        101.24                   Fog
# 2                7            4.0        101.26  Freezing Drizzle,Fog
# 3                6            4.0        101.27  Freezing Drizzle,Fog
# 4                7            4.8        101.23                   Fog

# %%
filt = df['Wind_Speed_Km/H'] == 4  #create a condition where spped is 4km/h
df.loc[filt, 'Wind_Speed_Km/H'].count()      #counts number of rows through which the condition filt is satsfied
# Out:
# 474

# %% [markdown]
# The wind speed was 4 km/h in 474 times

# %% [markdown]
# #### Q4:What is the mean vissibility

# %%
#view the dataset again
df.head(2)
# Out:
#             Date/Time  Temperature_C  Dew_Point_Temp_C  Relative_Humidity_%  \
# 0 2012-01-01 00:00:00           -1.8              -3.9                   86
# 1 2012-01-01 01:00:00           -1.8              -3.7                   87
#
#    Wind_Speed_Km/H  Visibility_Km  Pressure_Kpa Weather
# 0                4            8.0        101.24     Fog
# 1                4            8.0        101.24     Fog

# %%
df['Visibility_Km'].mean(axis=0)      # mean is calculated along the rows or horizontally
# Out:
# 27.66444672131151

# %% [markdown]
# mean vissibility is 27.67

# %% [markdown]
# #### Q5: What is the standard deviation of pressure in this data

# %%
df['Pressure_Kpa'].std(axis=0)   #calculating the standard variation axis =0 thats horizontally
# Out:
# 0.8440047459486474

# %% [markdown]
# standard deviation is 0.844

# %% [markdown]
# #### Q6: What is the variance of the relative humidity

# %%
df['Relative_Humidity_%'].var()   #calculating the variance axis =0 thats horizontally
# Out:
# 286.2485501984998

# %% [markdown]
# #### Q7: Create the column of day_name, month and year

# %%
df['day_name'] = df['Date/Time'].dt.day_name()    #inserting the column in all three occasion
df['month'] = df['Date/Time'].dt.month         #creating the month column
df['year'] = df['Date/Time'].dt.year         #creating the year column

df.head(1)              #review of the dataframe with added columns
# Out:
#    Date/Time  Temperature_C  Dew_Point_Temp_C  Relative_Humidity_%  \
# 0 2012-01-01           -1.8              -3.9                   86
#
#    Wind_Speed_Km/H  Visibility_Km  Pressure_Kpa Weather day_name  month  year
# 0                4            8.0        101.24     Fog   Sunday      1  2012

# %% [markdown]
# * The df has added in 3 columns
# * hoever the month column is in numerical form, hence it needs to be changed to actual months

# %%
#replace the numbers in the month column of the dataset, to actual month names

df['month'] = df['month'].replace({1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', 7:'Jul', 8:'Aug', 9:'Sep', 10:'Oct',
                                  11:'Nov', 12:'Dec'})

# %%
#check the dataset the month column
df['month'].head()
# Out:
# 0    Jan
# 1    Jan
# 2    Jan
# 3    Jan
# 4    Jan
# Name: month, dtype: object

# %% [markdown]
# #### Q8:Find all the instance when wind speed is above 24 and vissibility is 25

# %%
df.head(1)
# Out:
#    Date/Time  Temperature_C  Dew_Point_Temp_C  Relative_Humidity_%  \
# 0 2012-01-01           -1.8              -3.9                   86
#
#    Wind_Speed_Km/H  Visibility_Km  Pressure_Kpa Weather day_name month  year
# 0                4            8.0        101.24     Fog   Sunday   Jan  2012

# %%
filt = (df['Wind_Speed_Km/H'] > 24) & (df['Wind_Speed_Km/H'] > 25)                  #2 conditions to be met
df[filt]
# Out:
#                Date/Time  Temperature_C  Dew_Point_Temp_C  \
# 23   2012-01-01 23:00:00            5.3               2.0
# 24   2012-01-02 00:00:00            5.2               1.5
# 25   2012-01-02 01:00:00            4.6               0.0
# 26   2012-01-02 02:00:00            3.9              -0.9
# 27   2012-01-02 03:00:00            3.7              -1.5
# ...                  ...            ...               ...
# 8760 2012-12-31 00:00:00          -11.1             -14.4
# 8779 2012-12-31 19:00:00            0.1              -2.7
# 8781 2012-12-31 21:00:00           -0.5              -1.5
# 8782 2012-12-31 22:00:00           -0.2              -1.8
# 8783 2012-12-31 23:00:00            0.0              -2.1
#
#       Relative_Humidity_%  Wind_Speed_Km/H  Visibility_Km  Pressure_Kpa  \
# 23                     79               30           25.0         99.31
# 24                     77               35           25.0         99.26
# 25                     72               39           25.0         99.26
# 26                     71               32           25.0         99.26
# 27                     69               33           25.0         99.30
# ...                   ...              ...            ...           ...
# 8760                   77               26           25.0        101.51
# 8779                   81               30            9.7        100.13
# 8781                   93               28            4.8         99.95
# 8782                   89               28            9.7         99.91
# 8783                   86               30           11.3         99.89
#
#             Weather day_name month  year
# 23           Cloudy   Sunday   Jan  2012
# 24     Rain Showers   Monday   Jan  2012
# 25           Cloudy   Monday   Jan  2012
# 26    Mostly Cloudy   Monday   Jan  2012
# 27    Mostly Cloudy   Monday   Jan  2012
# ...             ...      ...   ...   ...
# 8760         Cloudy   Monday   Dec  2012
# 8779           Snow   Monday   Dec  2012
# 8781           Snow   Monday   Dec  2012
# 8782           Snow   Monday   Dec  2012
# 8783           Snow   Monday   Dec  2012
#
# [1047 rows x 11 columns]

# %% [markdown]
# it occured 232 time

# %% [markdown]
# #### Q9: on which day was the humidity high

# %%
df.groupby('day_name')['Relative_Humidity_%'].max().sort_values(ascending=False)    #sort with biggest, hence ascending =False
# Out:
# day_name
# Saturday     100
# Sunday       100
# Thursday     100
# Tuesday      100
# Wednesday    100
# Friday        99
# Monday        99
# Name: Relative_Humidity_%, dtype: int64

# %% [markdown]
# max humidity was 100 in 5 days

# %% [markdown]
# #### Q10: which month had the temperatures less than -22 degrees celcius

# %%
filt = df['Temperature_C'] < -22            #inserting a conditon to be met
df[filt]['month']
# Out:
# 342    Jan
# 343    Jan
# 344    Jan
# 345    Jan
# Name: month, dtype: object

# %% [markdown]
# #### Q11: find the correlation of the data set

# %%
df.corr()   #finding the correlation of the fields
# Out:
#                      Temperature_C  Dew_Point_Temp_C  Relative_Humidity_%  \
# Temperature_C             1.000000          0.932714            -0.220182
# Dew_Point_Temp_C          0.932714          1.000000             0.139494
# Relative_Humidity_%      -0.220182          0.139494             1.000000
# Wind_Speed_Km/H          -0.061876         -0.095685            -0.092743
# Visibility_Km             0.273455          0.050813            -0.633683
# Pressure_Kpa             -0.236389         -0.320616            -0.231424
# year                           NaN               NaN                  NaN
#
#                      Wind_Speed_Km/H  Visibility_Km  Pressure_Kpa  year
# Temperature_C              -0.061876       0.273455     -0.236389   NaN
# Dew_Point_Temp_C           -0.095685       0.050813     -0.320616   NaN
# Relative_Humidity_%        -0.092743      -0.633683     -0.231424   NaN
# Wind_Speed_Km/H             1.000000       0.004883     -0.356613   NaN
# Visibility_Km               0.004883       1.000000      0.231847   NaN
# Pressure_Kpa               -0.356613       0.231847      1.000000   NaN
# year                             NaN            NaN           NaN   NaN

# %% [markdown]
# * There is strong relationship only between the temp and the dew_point_temp_c
# * there is a good relationship between the vissibility and humidity in a negative way

# %% [markdown]
# #### plot the visuals

# %%
sns.regplot(df['Temperature_C'], df['Dew_Point_Temp_C'], data=df) #taking in 2 columns to check for their correlation
# Out:
# C:\Users\Tamie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Temperature_C', ylabel='Dew_Point_Temp_C'>

# %% [markdown]
# There is a strong correlation between the temp and the dew point temp as one increases the other incraeses as well

# %%
sns.regplot(df['Visibility_Km'], df['Dew_Point_Temp_C'], data=df)
#plt.scatter(df['visibility_km'], df['dew_point_temp_c'])
# Out:
# <AxesSubplot:xlabel='Visibility_Km', ylabel='Dew_Point_Temp_C'>

# %% [markdown]
# * the data is widely spread, it can be hard to tell the events taking place indicating a week correlation

# %% [markdown]
# #### Q12: find all instances when the snow was recorded

# %%
df[df['Weather'].str.contains('Snow')]   #checks the column weather for anyword with python in it to deal with it
# Out:
#                Date/Time  Temperature_C  Dew_Point_Temp_C  \
# 41   2012-01-02 17:00:00           -2.1              -9.5
# 44   2012-01-02 20:00:00           -5.6             -13.4
# 45   2012-01-02 21:00:00           -5.8             -12.8
# 47   2012-01-02 23:00:00           -7.4             -14.1
# 48   2012-01-03 00:00:00           -9.0             -16.0
# ...                  ...            ...               ...
# 8779 2012-12-31 19:00:00            0.1              -2.7
# 8780 2012-12-31 20:00:00            0.2              -2.4
# 8781 2012-12-31 21:00:00           -0.5              -1.5
# 8782 2012-12-31 22:00:00           -0.2              -1.8
# 8783 2012-12-31 23:00:00            0.0              -2.1
#
#       Relative_Humidity_%  Wind_Speed_Km/H  Visibility_Km  Pressure_Kpa  \
# 41                     57               22           25.0         99.66
# 44                     54               24           25.0        100.07
# 45                     58               26           25.0        100.15
# 47                     59               17           19.3        100.27
# 48                     57               28           25.0        100.35
# ...                   ...              ...            ...           ...
# 8779                   81               30            9.7        100.13
# 8780                   83               24            9.7        100.03
# 8781                   93               28            4.8         99.95
# 8782                   89               28            9.7         99.91
# 8783                   86               30           11.3         99.89
#
#            Weather day_name month  year
# 41    Snow Showers   Monday   Jan  2012
# 44    Snow Showers   Monday   Jan  2012
# 45    Snow Showers   Monday   Jan  2012
# 47    Snow Showers   Monday   Jan  2012
# 48    Snow Showers  Tuesday   Jan  2012
# ...            ...      ...   ...   ...
# 8779          Snow   Monday   Dec  2012
# 8780          Snow   Monday   Dec  2012
# 8781          Snow   Monday   Dec  2012
# 8782          Snow   Monday   Dec  2012
# 8783          Snow   Monday   Dec  2012
#
# [583 rows x 11 columns]

# %% [markdown]
# It was recorded on 583 conditions

# %% [markdown]
# #### Q13: what was the mean weather monthly throughout the year

# %%
df.groupby('month').Temperature_C.mean().sort_values(ascending=False)   #group the temp by month
# Out:
# month
# Jul    22.790054
# Aug    22.279301
# Jun    20.134028
# Sep    16.484444
# May    16.237769
# Oct    10.954973
# Apr     7.009306
# Mar     3.121237
# Nov     0.931389
# Dec    -3.306317
# Feb    -4.225000
# Jan    -7.371505
# Name: Temperature_C, dtype: float64

# %% [markdown]
# July had the highest mean temperaratures and january had the lowest temperature

# %% [markdown]
# #### Q14: what is the mean value of each column against each  'weather column)

# %%
df.head(3)
# Out:
#             Date/Time  Temperature_C  Dew_Point_Temp_C  Relative_Humidity_%  \
# 0 2012-01-01 00:00:00           -1.8              -3.9                   86
# 1 2012-01-01 01:00:00           -1.8              -3.7                   87
# 2 2012-01-01 02:00:00           -1.8              -3.4                   89
#
#    Wind_Speed_Km/H  Visibility_Km  Pressure_Kpa               Weather  \
# 0                4            8.0        101.24                   Fog
# 1                4            8.0        101.24                   Fog
# 2                7            4.0        101.26  Freezing Drizzle,Fog
#
#   day_name month  year
# 0   Sunday   Jan  2012
# 1   Sunday   Jan  2012
# 2   Sunday   Jan  2012

# %%
df.groupby('Weather').mean().head()
# Out:
#                          Temperature_C  Dew_Point_Temp_C  Relative_Humidity_%  \
# Weather
# Clear                         6.825716          0.089367            64.497738
# Cloudy                        7.970544          2.375810            69.592593
# Drizzle                       7.353659          5.504878            88.243902
# Drizzle,Fog                   8.067500          7.033750            93.275000
# Drizzle,Ice Pellets,Fog       0.400000         -0.700000            92.000000
#
#                          Wind_Speed_Km/H  Visibility_Km  Pressure_Kpa    year
# Weather
# Clear                          10.557315      30.153243    101.587443  2012.0
# Cloudy                         16.127315      26.625752    100.911441  2012.0
# Drizzle                        16.097561      17.931707    100.435366  2012.0
# Drizzle,Fog                    11.862500       5.257500    100.786625  2012.0
# Drizzle,Ice Pellets,Fog        20.000000       4.000000    100.790000  2012.0

# %% [markdown]
# #### Q15: what is the min and max value of each column against each weather condition

# %%
df.groupby('Weather').min()
# Out:
#                                                   Date/Time  Temperature_C  \
# Weather
# Clear                                   2012-01-03 19:00:00          -23.3
# Cloudy                                  2012-01-01 17:00:00          -21.4
# Drizzle                                 2012-01-23 21:00:00            1.1
# Drizzle,Fog                             2012-01-23 20:00:00            0.0
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00            0.4
# Drizzle,Snow                            2012-12-17 15:00:00            0.9
# Drizzle,Snow,Fog                        2012-12-18 21:00:00            0.3
# Fog                                     2012-01-01 00:00:00          -16.0
# Freezing Drizzle                        2012-01-07 11:00:00           -9.0
# Freezing Drizzle,Fog                    2012-01-01 02:00:00           -6.4
# Freezing Drizzle,Haze                   2012-02-01 11:00:00           -5.8
# Freezing Drizzle,Snow                   2012-01-13 03:00:00           -8.3
# Freezing Fog                            2012-01-22 06:00:00          -19.0
# Freezing Rain                           2012-01-07 10:00:00           -6.5
# Freezing Rain,Fog                       2012-01-07 09:00:00           -6.1
# Freezing Rain,Haze                      2012-02-01 14:00:00           -4.9
# Freezing Rain,Ice Pellets,Fog           2012-12-17 03:00:00           -2.6
# Freezing Rain,Snow Grains               2012-01-13 09:00:00           -5.0
# Haze                                    2012-01-22 12:00:00          -11.5
# Mainly Clear                            2012-01-02 12:00:00          -22.8
# Moderate Rain,Fog                       2012-12-10 08:00:00            1.7
# Moderate Snow                           2012-01-12 15:00:00           -6.3
# Moderate Snow,Blowing Snow              2012-12-27 10:00:00           -5.5
# Mostly Cloudy                           2012-01-01 16:00:00          -23.2
# Rain                                    2012-01-01 18:00:00            0.3
# Rain Showers                            2012-01-01 22:00:00            1.6
# Rain Showers,Fog                        2012-10-20 03:00:00           12.8
# Rain Showers,Snow Showers               2012-11-04 08:00:00            2.1
# Rain,Fog                                2012-01-23 18:00:00            0.0
# Rain,Haze                               2012-03-13 07:00:00            4.0
# Rain,Ice Pellets                        2012-12-18 05:00:00            0.6
# Rain,Snow                               2012-01-10 05:00:00            0.6
# Rain,Snow Grains                        2012-12-21 00:00:00            1.9
# Rain,Snow,Fog                           2012-12-08 21:00:00            0.8
# Rain,Snow,Ice Pellets                   2012-12-21 01:00:00            0.9
# Snow                                    2012-01-03 07:00:00          -16.7
# Snow Pellets                            2012-11-24 15:00:00            0.7
# Snow Showers                            2012-01-02 17:00:00          -13.3
# Snow Showers,Fog                        2012-12-26 09:00:00          -11.3
# Snow,Blowing Snow                       2012-01-13 21:00:00          -12.0
# Snow,Fog                                2012-02-10 23:00:00          -10.1
# Snow,Haze                               2012-02-01 17:00:00           -4.3
# Snow,Ice Pellets                        2012-03-03 04:00:00           -4.3
# Thunderstorms                           2012-07-04 16:00:00           21.6
# Thunderstorms,Heavy Rain Showers        2012-05-29 06:00:00           10.9
# Thunderstorms,Moderate Rain Showers,Fog 2012-07-17 06:00:00           19.6
# Thunderstorms,Rain                      2012-05-25 20:00:00           19.4
# Thunderstorms,Rain Showers              2012-05-29 04:00:00           11.0
# Thunderstorms,Rain Showers,Fog          2012-06-29 03:00:00           19.5
# Thunderstorms,Rain,Fog                  2012-07-17 05:00:00           20.6
#
#                                          Dew_Point_Temp_C  \
# Weather
# Clear                                               -28.5
# Cloudy                                              -26.8
# Drizzle                                              -0.2
# Drizzle,Fog                                          -1.6
# Drizzle,Ice Pellets,Fog                              -0.7
# Drizzle,Snow                                          0.1
# Drizzle,Snow,Fog                                     -0.1
# Fog                                                 -17.2
# Freezing Drizzle                                    -12.2
# Freezing Drizzle,Fog                                 -9.0
# Freezing Drizzle,Haze                                -8.3
# Freezing Drizzle,Snow                               -10.4
# Freezing Fog                                        -22.9
# Freezing Rain                                        -9.0
# Freezing Rain,Fog                                    -8.7
# Freezing Rain,Haze                                   -7.5
# Freezing Rain,Ice Pellets,Fog                        -3.7
# Freezing Rain,Snow Grains                            -7.3
# Haze                                                -16.0
# Mainly Clear                                        -28.0
# Moderate Rain,Fog                                     0.8
# Moderate Snow                                        -7.6
# Moderate Snow,Blowing Snow                           -6.6
# Mostly Cloudy                                       -28.5
# Rain                                                 -5.7
# Rain Showers                                         -7.2
# Rain Showers,Fog                                     12.1
# Rain Showers,Snow Showers                            -1.8
# Rain,Fog                                             -1.2
# Rain,Haze                                             1.0
# Rain,Ice Pellets                                     -0.6
# Rain,Snow                                            -1.7
# Rain,Snow Grains                                     -2.1
# Rain,Snow,Fog                                         0.3
# Rain,Snow,Ice Pellets                                -0.7
# Snow                                                -24.6
# Snow Pellets                                         -6.4
# Snow Showers                                        -19.3
# Snow Showers,Fog                                    -12.7
# Snow,Blowing Snow                                   -16.2
# Snow,Fog                                            -12.0
# Snow,Haze                                            -7.2
# Snow,Ice Pellets                                     -5.9
# Thunderstorms                                        19.4
# Thunderstorms,Heavy Rain Showers                      9.0
# Thunderstorms,Moderate Rain Showers,Fog              18.5
# Thunderstorms,Rain                                   18.2
# Thunderstorms,Rain Showers                            7.0
# Thunderstorms,Rain Showers,Fog                       16.1
# Thunderstorms,Rain,Fog                               18.6
#
#                                          Relative_Humidity_%  Wind_Speed_Km/H  \
# Weather
# Clear                                                     20                0
# Cloudy                                                    18                0
# Drizzle                                                   74                0
# Drizzle,Fog                                               85                0
# Drizzle,Ice Pellets,Fog                                   92               20
# Drizzle,Snow                                              92                9
# Drizzle,Snow,Fog                                          92                7
# Fog                                                       80                0
# Freezing Drizzle                                          78                6
# Freezing Drizzle,Fog                                      82                6
# Freezing Drizzle,Haze                                     81                9
# Freezing Drizzle,Snow                                     79                6
# Freezing Fog                                              71                0
# Freezing Rain                                             81                7
# Freezing Rain,Fog                                         82                7
# Freezing Rain,Haze                                        82                6
# Freezing Rain,Ice Pellets,Fog                             92               28
# Freezing Rain,Snow Grains                                 84               32
# Haze                                                      68                0
# Mainly Clear                                              20                0
# Moderate Rain,Fog                                         94               17
# Moderate Snow                                             83               26
# Moderate Snow,Blowing Snow                                92               39
# Mostly Cloudy                                             18                0
# Rain                                                      40                0
# Rain Showers                                              37                0
# Rain Showers,Fog                                          96               13
# Rain Showers,Snow Showers                                 75               17
# Rain,Fog                                                  83                0
# Rain,Haze                                                 81                7
# Rain,Ice Pellets                                          92               24
# Rain,Snow                                                 81               13
# Rain,Snow Grains                                          75               26
# Rain,Snow,Fog                                             96                9
# Rain,Snow,Ice Pellets                                     88               17
# Snow                                                      41                0
# Snow Pellets                                              59               35
# Snow Showers                                              52                0
# Snow Showers,Fog                                          89                7
# Snow,Blowing Snow                                         70               24
# Snow,Fog                                                  77                4
# Snow,Haze                                                 80                0
# Snow,Ice Pellets                                          76               19
# Thunderstorms                                             67                0
# Thunderstorms,Heavy Rain Showers                          88                9
# Thunderstorms,Moderate Rain Showers,Fog                   93               15
# Thunderstorms,Rain                                        83                4
# Thunderstorms,Rain Showers                                68                7
# Thunderstorms,Rain Showers,Fog                            80                7
# Thunderstorms,Rain,Fog                                    88               19
#
#                                          Visibility_Km  Pressure_Kpa  \
# Weather
# Clear                                             11.3         99.52
# Cloudy                                            11.3         98.39
# Drizzle                                            6.4         97.84
# Drizzle,Fog                                        1.0         98.65
# Drizzle,Ice Pellets,Fog                            4.0        100.79
# Drizzle,Snow                                       9.7        100.63
# Drizzle,Snow,Fog                                   2.4         97.79
# Fog                                                0.2         98.31
# Freezing Drizzle                                   4.8         98.44
# Freezing Drizzle,Fog                               3.6         98.74
# Freezing Drizzle,Haze                              2.0        100.28
# Freezing Drizzle,Snow                              2.4         99.19
# Freezing Fog                                       0.2        101.97
# Freezing Rain                                      2.8         98.22
# Freezing Rain,Fog                                  2.8         98.32
# Freezing Rain,Haze                                 2.0        100.34
# Freezing Rain,Ice Pellets,Fog                      8.0        100.95
# Freezing Rain,Snow Grains                          4.8         98.56
# Haze                                               4.8        100.35
# Mainly Clear                                      12.9         98.67
# Moderate Rain,Fog                                  6.4         99.98
# Moderate Snow                                      0.6         99.88
# Moderate Snow,Blowing Snow                         0.6        100.50
# Mostly Cloudy                                     11.3         98.36
# Rain                                               4.0         97.52
# Rain Showers                                       6.4         98.51
# Rain Showers,Fog                                   6.4         99.83
# Rain Showers,Snow Showers                         19.3        101.09
# Rain,Fog                                           2.0         98.61
# Rain,Haze                                          4.0        100.50
# Rain,Ice Pellets                                   9.7        100.12
# Rain,Snow                                          2.4         98.18
# Rain,Snow Grains                                  25.0        100.60
# Rain,Snow,Fog                                      6.4        100.73
# Rain,Snow,Ice Pellets                              4.8         99.85
# Snow                                               1.0         97.75
# Snow Pellets                                       2.4         99.70
# Snow Showers                                       2.4         99.49
# Snow Showers,Fog                                   4.0        100.63
# Snow,Blowing Snow                                  0.6         98.11
# Snow,Fog                                           1.2         99.38
# Snow,Haze                                          4.0        100.61
# Snow,Ice Pellets                                   2.8         99.40
# Thunderstorms                                     24.1         99.84
# Thunderstorms,Heavy Rain Showers                   2.4        100.26
# Thunderstorms,Moderate Rain Showers,Fog            3.2        100.01
# Thunderstorms,Rain                                16.1        100.19
# Thunderstorms,Rain Showers                         6.4         99.65
# Thunderstorms,Rain Showers,Fog                     9.7         99.71
# Thunderstorms,Rain,Fog                             4.8        100.08
#
#                                           day_name month  year
# Weather
# Clear                                       Friday   Apr  2012
# Cloudy                                      Friday   Apr  2012
# Drizzle                                     Friday   Aug  2012
# Drizzle,Fog                                 Friday   Apr  2012
# Drizzle,Ice Pellets,Fog                     Monday   Dec  2012
# Drizzle,Snow                                Monday   Dec  2012
# Drizzle,Snow,Fog                            Friday   Dec  2012
# Fog                                         Friday   Apr  2012
# Freezing Drizzle                            Friday   Dec  2012
# Freezing Drizzle,Fog                        Friday   Dec  2012
# Freezing Drizzle,Haze                    Wednesday   Feb  2012
# Freezing Drizzle,Snow                       Friday   Dec  2012
# Freezing Fog                              Saturday   Feb  2012
# Freezing Rain                               Friday   Dec  2012
# Freezing Rain,Fog                           Monday   Dec  2012
# Freezing Rain,Haze                       Wednesday   Feb  2012
# Freezing Rain,Ice Pellets,Fog               Monday   Dec  2012
# Freezing Rain,Snow Grains                   Friday   Jan  2012
# Haze                                      Saturday   Dec  2012
# Mainly Clear                                Friday   Apr  2012
# Moderate Rain,Fog                           Monday   Dec  2012
# Moderate Snow                             Thursday   Dec  2012
# Moderate Snow,Blowing Snow                Thursday   Dec  2012
# Mostly Cloudy                               Friday   Apr  2012
# Rain                                        Friday   Apr  2012
# Rain Showers                                Friday   Apr  2012
# Rain Showers,Fog                          Saturday   Oct  2012
# Rain Showers,Snow Showers                   Sunday   Dec  2012
# Rain,Fog                                    Friday   Apr  2012
# Rain,Haze                                  Tuesday   Mar  2012
# Rain,Ice Pellets                           Tuesday   Dec  2012
# Rain,Snow                                   Friday   Apr  2012
# Rain,Snow Grains                            Friday   Dec  2012
# Rain,Snow,Fog                             Saturday   Dec  2012
# Rain,Snow,Ice Pellets                       Friday   Dec  2012
# Snow                                        Friday   Apr  2012
# Snow Pellets                              Saturday   Nov  2012
# Snow Showers                                Friday   Dec  2012
# Snow Showers,Fog                          Saturday   Dec  2012
# Snow,Blowing Snow                           Friday   Dec  2012
# Snow,Fog                                    Friday   Dec  2012
# Snow,Haze                                Wednesday   Feb  2012
# Snow,Ice Pellets                            Monday   Dec  2012
# Thunderstorms                               Monday   Jul  2012
# Thunderstorms,Heavy Rain Showers           Tuesday   May  2012
# Thunderstorms,Moderate Rain Showers,Fog    Tuesday   Jul  2012
# Thunderstorms,Rain                          Friday   Jul  2012
# Thunderstorms,Rain Showers                  Friday   Aug  2012
# Thunderstorms,Rain Showers,Fog              Friday   Jul  2012
# Thunderstorms,Rain,Fog                     Tuesday   Jul  2012

# %%
df.groupby('Weather').max()
# Out:
#                                                   Date/Time  Temperature_C  \
# Weather
# Clear                                   2012-12-30 20:00:00           32.8
# Cloudy                                  2012-12-31 06:00:00           30.5
# Drizzle                                 2012-12-22 01:00:00           18.8
# Drizzle,Fog                             2012-12-19 10:00:00           19.9
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00            0.4
# Drizzle,Snow                            2012-12-19 18:00:00            1.2
# Drizzle,Snow,Fog                        2012-12-22 03:00:00            1.1
# Fog                                     2012-12-29 10:00:00           20.8
# Freezing Drizzle                        2012-12-17 00:00:00           -2.3
# Freezing Drizzle,Fog                    2012-12-10 05:00:00           -0.3
# Freezing Drizzle,Haze                   2012-02-01 13:00:00           -5.0
# Freezing Drizzle,Snow                   2012-12-28 02:00:00           -3.3
# Freezing Fog                            2012-03-17 06:00:00           -0.1
# Freezing Rain                           2012-12-17 02:00:00            0.3
# Freezing Rain,Fog                       2012-12-17 01:00:00            0.1
# Freezing Rain,Haze                      2012-02-01 15:00:00           -4.9
# Freezing Rain,Ice Pellets,Fog           2012-12-17 03:00:00           -2.6
# Freezing Rain,Snow Grains               2012-01-13 09:00:00           -5.0
# Haze                                    2012-12-13 12:00:00           14.1
# Mainly Clear                            2012-12-30 22:00:00           33.0
# Moderate Rain,Fog                       2012-12-10 08:00:00            1.7
# Moderate Snow                           2012-12-27 09:00:00           -4.9
# Moderate Snow,Blowing Snow              2012-12-27 12:00:00           -5.4
# Mostly Cloudy                           2012-12-31 03:00:00           32.4
# Rain                                    2012-12-21 21:00:00           22.8
# Rain Showers                            2012-12-14 11:00:00           26.4
# Rain Showers,Fog                        2012-10-20 03:00:00           12.8
# Rain Showers,Snow Showers               2012-12-05 10:00:00            2.2
# Rain,Fog                                2012-12-10 17:00:00           21.7
# Rain,Haze                               2012-03-13 09:00:00            5.5
# Rain,Ice Pellets                        2012-12-18 05:00:00            0.6
# Rain,Snow                               2012-12-21 09:00:00            1.7
# Rain,Snow Grains                        2012-12-21 00:00:00            1.9
# Rain,Snow,Fog                           2012-12-08 21:00:00            0.8
# Rain,Snow,Ice Pellets                   2012-12-21 05:00:00            1.3
# Snow                                    2012-12-31 23:00:00            3.7
# Snow Pellets                            2012-11-24 15:00:00            0.7
# Snow Showers                            2012-12-31 08:00:00            2.9
# Snow Showers,Fog                        2012-12-29 13:00:00          -10.0
# Snow,Blowing Snow                       2012-12-27 19:00:00           -1.4
# Snow,Fog                                2012-12-31 10:00:00            1.1
# Snow,Haze                               2012-02-01 21:00:00           -3.6
# Snow,Ice Pellets                        2012-12-17 06:00:00            0.8
# Thunderstorms                           2012-07-16 01:00:00           26.7
# Thunderstorms,Heavy Rain Showers        2012-05-29 06:00:00           10.9
# Thunderstorms,Moderate Rain Showers,Fog 2012-07-17 06:00:00           19.6
# Thunderstorms,Rain                      2012-07-23 18:00:00           21.3
# Thunderstorms,Rain Showers              2012-09-14 20:00:00           25.5
# Thunderstorms,Rain Showers,Fog          2012-07-31 20:00:00           22.9
# Thunderstorms,Rain,Fog                  2012-07-17 05:00:00           20.6
#
#                                          Dew_Point_Temp_C  \
# Weather
# Clear                                                20.4
# Cloudy                                               22.6
# Drizzle                                              17.7
# Drizzle,Fog                                          19.1
# Drizzle,Ice Pellets,Fog                              -0.7
# Drizzle,Snow                                          0.2
# Drizzle,Snow,Fog                                      0.6
# Fog                                                  19.6
# Freezing Drizzle                                     -3.3
# Freezing Drizzle,Fog                                 -2.3
# Freezing Drizzle,Haze                                -7.7
# Freezing Drizzle,Snow                                -4.6
# Freezing Fog                                         -0.3
# Freezing Rain                                        -1.7
# Freezing Rain,Fog                                    -0.9
# Freezing Rain,Haze                                   -7.4
# Freezing Rain,Ice Pellets,Fog                        -3.7
# Freezing Rain,Snow Grains                            -7.3
# Haze                                                 11.1
# Mainly Clear                                         21.2
# Moderate Rain,Fog                                     0.8
# Moderate Snow                                        -6.7
# Moderate Snow,Blowing Snow                           -6.4
# Mostly Cloudy                                        24.4
# Rain                                                 20.4
# Rain Showers                                         23.0
# Rain Showers,Fog                                     12.1
# Rain Showers,Snow Showers                            -1.2
# Rain,Fog                                             19.5
# Rain,Haze                                             2.9
# Rain,Ice Pellets                                     -0.6
# Rain,Snow                                             0.5
# Rain,Snow Grains                                     -2.1
# Rain,Snow,Fog                                         0.3
# Rain,Snow,Ice Pellets                                 0.1
# Snow                                                  0.3
# Snow Pellets                                         -6.4
# Snow Showers                                         -0.7
# Snow Showers,Fog                                    -11.1
# Snow,Blowing Snow                                    -2.9
# Snow,Fog                                              0.8
# Snow,Haze                                            -6.4
# Snow,Ice Pellets                                     -1.7
# Thunderstorms                                        20.1
# Thunderstorms,Heavy Rain Showers                      9.0
# Thunderstorms,Moderate Rain Showers,Fog              18.5
# Thunderstorms,Rain                                   19.1
# Thunderstorms,Rain Showers                           23.1
# Thunderstorms,Rain Showers,Fog                       21.3
# Thunderstorms,Rain,Fog                               18.6
#
#                                          Relative_Humidity_%  Wind_Speed_Km/H  \
# Weather
# Clear                                                     99               33
# Cloudy                                                    99               54
# Drizzle                                                   96               30
# Drizzle,Fog                                              100               28
# Drizzle,Ice Pellets,Fog                                   92               20
# Drizzle,Snow                                              95               19
# Drizzle,Snow,Fog                                          98               32
# Fog                                                      100               22
# Freezing Drizzle                                          93               26
# Freezing Drizzle,Fog                                      94               33
# Freezing Drizzle,Haze                                     83               11
# Freezing Drizzle,Snow                                     94               24
# Freezing Fog                                              99                9
# Freezing Rain                                             92               28
# Freezing Rain,Fog                                         93               26
# Freezing Rain,Haze                                        83                9
# Freezing Rain,Ice Pellets,Fog                             92               28
# Freezing Rain,Snow Grains                                 84               32
# Haze                                                      86               17
# Mainly Clear                                              99               63
# Moderate Rain,Fog                                         94               17
# Moderate Snow                                             93               39
# Moderate Snow,Blowing Snow                                93               41
# Mostly Cloudy                                            100               83
# Rain                                                      99               52
# Rain Showers                                              97               41
# Rain Showers,Fog                                          96               13
# Rain Showers,Snow Showers                                 78               28
# Rain,Fog                                                 100               46
# Rain,Haze                                                 86               17
# Rain,Ice Pellets                                          92               24
# Rain,Snow                                                 94               52
# Rain,Snow Grains                                          75               26
# Rain,Snow,Fog                                             96                9
# Rain,Snow,Ice Pellets                                     94               28
# Snow                                                      96               57
# Snow Pellets                                              59               35
# Snow Showers                                              94               37
# Snow Showers,Fog                                          92               22
# Snow,Blowing Snow                                         91               48
# Snow,Fog                                                  99               35
# Snow,Haze                                                 81               15
# Snow,Ice Pellets                                          92               33
# Thunderstorms                                             87               15
# Thunderstorms,Heavy Rain Showers                          88                9
# Thunderstorms,Moderate Rain Showers,Fog                   93               15
# Thunderstorms,Rain                                        93               30
# Thunderstorms,Rain Showers                                98               32
# Thunderstorms,Rain Showers,Fog                            91               35
# Thunderstorms,Rain,Fog                                    88               19
#
#                                          Visibility_Km  Pressure_Kpa  \
# Weather
# Clear                                             48.3        103.63
# Cloudy                                            48.3        103.65
# Drizzle                                           25.0        101.56
# Drizzle,Fog                                        9.7        102.07
# Drizzle,Ice Pellets,Fog                            4.0        100.79
# Drizzle,Snow                                      11.3        101.15
# Drizzle,Snow,Fog                                   9.7        100.15
# Fog                                                9.7        103.04
# Freezing Drizzle                                  12.9        101.02
# Freezing Drizzle,Fog                               8.0        101.27
# Freezing Drizzle,Haze                              4.0        100.36
# Freezing Drizzle,Snow                             12.9        101.18
# Freezing Fog                                       0.8        102.85
# Freezing Rain                                     16.1        101.00
# Freezing Rain,Fog                                  9.7        101.01
# Freezing Rain,Haze                                 2.8        100.41
# Freezing Rain,Ice Pellets,Fog                      8.0        100.95
# Freezing Rain,Snow Grains                          4.8         98.56
# Haze                                               9.7        102.97
# Mainly Clear                                      48.3        103.59
# Moderate Rain,Fog                                  6.4         99.98
# Moderate Snow                                      0.8        100.67
# Moderate Snow,Blowing Snow                         0.6        100.64
# Mostly Cloudy                                     48.3        103.65
# Rain                                              48.3        102.26
# Rain Showers                                      48.3        102.31
# Rain Showers,Fog                                   6.4         99.83
# Rain Showers,Snow Showers                         24.1        101.11
# Rain,Fog                                           9.7        101.77
# Rain,Haze                                          9.7        100.61
# Rain,Ice Pellets                                   9.7        100.12
# Rain,Snow                                         25.0        101.07
# Rain,Snow Grains                                  25.0        100.60
# Rain,Snow,Fog                                      6.4        100.73
# Rain,Snow,Ice Pellets                              6.4        100.47
# Snow                                              25.0        102.73
# Snow Pellets                                       2.4         99.70
# Snow Showers                                      48.3        102.50
# Snow Showers,Fog                                   9.7        102.52
# Snow,Blowing Snow                                  9.7        100.62
# Snow,Fog                                           9.7        102.07
# Snow,Haze                                          6.4        100.99
# Snow,Ice Pellets                                  11.3        100.96
# Thunderstorms                                     25.0        100.62
# Thunderstorms,Heavy Rain Showers                   2.4        100.26
# Thunderstorms,Moderate Rain Showers,Fog            3.2        100.01
# Thunderstorms,Rain                                24.1        100.83
# Thunderstorms,Rain Showers                        25.0        101.06
# Thunderstorms,Rain Showers,Fog                     9.7        100.64
# Thunderstorms,Rain,Fog                             4.8        100.08
#
#                                           day_name month  year
# Weather
# Clear                                    Wednesday   Sep  2012
# Cloudy                                   Wednesday   Sep  2012
# Drizzle                                  Wednesday   Sep  2012
# Drizzle,Fog                              Wednesday   Sep  2012
# Drizzle,Ice Pellets,Fog                     Monday   Dec  2012
# Drizzle,Snow                             Wednesday   Dec  2012
# Drizzle,Snow,Fog                         Wednesday   Dec  2012
# Fog                                      Wednesday   Sep  2012
# Freezing Drizzle                         Wednesday   Jan  2012
# Freezing Drizzle,Fog                        Sunday   Jan  2012
# Freezing Drizzle,Haze                    Wednesday   Feb  2012
# Freezing Drizzle,Snow                      Tuesday   Mar  2012
# Freezing Fog                                Sunday   Mar  2012
# Freezing Rain                            Wednesday   Jan  2012
# Freezing Rain,Fog                          Tuesday   Jan  2012
# Freezing Rain,Haze                       Wednesday   Feb  2012
# Freezing Rain,Ice Pellets,Fog               Monday   Dec  2012
# Freezing Rain,Snow Grains                   Friday   Jan  2012
# Haze                                     Wednesday   Oct  2012
# Mainly Clear                             Wednesday   Sep  2012
# Moderate Rain,Fog                           Monday   Dec  2012
# Moderate Snow                             Thursday   Jan  2012
# Moderate Snow,Blowing Snow                Thursday   Dec  2012
# Mostly Cloudy                            Wednesday   Sep  2012
# Rain                                     Wednesday   Sep  2012
# Rain Showers                             Wednesday   Sep  2012
# Rain Showers,Fog                          Saturday   Oct  2012
# Rain Showers,Snow Showers                Wednesday   Nov  2012
# Rain,Fog                                 Wednesday   Sep  2012
# Rain,Haze                                  Tuesday   Mar  2012
# Rain,Ice Pellets                           Tuesday   Dec  2012
# Rain,Snow                                Wednesday   Jan  2012
# Rain,Snow Grains                            Friday   Dec  2012
# Rain,Snow,Fog                             Saturday   Dec  2012
# Rain,Snow,Ice Pellets                       Friday   Dec  2012
# Snow                                     Wednesday   Nov  2012
# Snow Pellets                              Saturday   Nov  2012
# Snow Showers                             Wednesday   Nov  2012
# Snow Showers,Fog                         Wednesday   Dec  2012
# Snow,Blowing Snow                         Thursday   Jan  2012
# Snow,Fog                                 Wednesday   Mar  2012
# Snow,Haze                                Wednesday   Feb  2012
# Snow,Ice Pellets                         Wednesday   Mar  2012
# Thunderstorms                            Wednesday   Jul  2012
# Thunderstorms,Heavy Rain Showers           Tuesday   May  2012
# Thunderstorms,Moderate Rain Showers,Fog    Tuesday   Jul  2012
# Thunderstorms,Rain                          Monday   May  2012
# Thunderstorms,Rain Showers               Wednesday   Sep  2012
# Thunderstorms,Rain Showers,Fog             Tuesday   Jun  2012
# Thunderstorms,Rain,Fog                     Tuesday   Jul  2012

# %% [markdown]
# # Phase 4: Data Visualisation

# %%
# Filter the data based on the weather condition
filt = df['Weather'] == 'Fog'
fog_count = df.loc[filt, 'Weather'].count()

# Create a bar chart of the fog count
fig, ax = plt.subplots()
ax.bar(['Fog'], [fog_count])

# Set the title and axis labels
ax.set_title('Number of Occurrences of Fog Weather Condition')
ax.set_xlabel('Weather Condition')
ax.set_ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# ##### * **key takeaway:**  fog occured more than 140 times

# %%
# Group the data by day_name and find the maximum Relative Humidity for each day
max_rh_by_day = df.groupby('day_name')['Relative_Humidity_%'].max().sort_values(ascending=False)

# Create a horizontal bar chart of the maximum Relative Humidity for each day
fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(max_rh_by_day.index, max_rh_by_day)

# Set the title and axis labels
ax.set_title('Maximum Relative Humidity by Day')
ax.set_xlabel('Relative Humidity (%)')
ax.set_ylabel('Day')

# Show the plot
plt.show()

# %% [markdown]
# ##### * **key takeaway:**  max humidity was there close to 100 in about 5 working days

# %%
import matplotlib.pyplot as plt

grouped = df.groupby('day_name')['Relative_Humidity_%'].mean().sort_values(ascending=False)

grouped.plot(kind='barh')

plt.title('Maximum Relative Humidity by Day')
plt.xlabel('Relative Humidity %')
plt.ylabel('Day')
plt.show()

# %% [markdown]
# ##### * **key takeaway:**  mean humidity was high mostly on tuesdays, the least being staurdays

# %% [markdown]
# ## Author: TamiriraIshe Nyevera
#
# ## Date: 3 January 2023
#
# * #### LinkedIn profile Link: [My LinkedIn Profile](https://www.linkedin.com/in/tamiriraishe-nyevera-2b51671b5/)
#
# * #### Github link:[Github profile](https://github.com/Tamie-AI-Tech)
#
# * #### Kaggle Link: [Kaggle Profile](https://www.kaggle.com/tamiriraishenyevera)
